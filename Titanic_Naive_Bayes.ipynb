# %%
import pandas as pd
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis='columns', inplace=True)
df.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
target = df.Survived
inputs = df.drop('Survived', axis='columns')

# %%
dummies = pd.get_dummies(inputs.Sex)
dummies.head(3)
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False

# %%
inputs = pd.concat([inputs, dummies], axis='columns')
inputs.head(3)
# Out:
#    Pclass     Sex   Age     Fare  female   male
# 0       3    male  22.0   7.2500   False   True
# 1       1  female  38.0  71.2833    True  False
# 2       3  female  26.0   7.9250    True  False

# %%
inputs.drop('Sex', axis='columns', inplace=True)
inputs.head(3)
# Out:
#    Pclass   Age     Fare  female   male
# 0       3  22.0   7.2500   False   True
# 1       1  38.0  71.2833    True  False
# 2       3  26.0   7.9250    True  False

# %%
inputs.columns[inputs.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
inputs.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())
inputs.head(6)
# Out:
#    Pclass        Age     Fare  female   male
# 0       3  22.000000   7.2500   False   True
# 1       1  38.000000  71.2833    True  False
# 2       3  26.000000   7.9250    True  False
# 3       1  35.000000  53.1000    True  False
# 4       3  35.000000   8.0500   False   True
# 5       3  29.699118   8.4583   False   True

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)

# %%
len(x_train)
# Out:
# 712

# %%
len(x_test)
# Out:
# 179

# %%
len(inputs)
# Out:
# 891

# %%
x_train
# Out:
#      Pclass        Age      Fare  female   male
# 573       3  29.699118    7.7500    True  False
# 330       3  29.699118   23.2500    True  False
# 871       1  47.000000   52.5542    True  False
# 85        3  33.000000   15.8500    True  False
# 746       3  16.000000   20.2500   False   True
# ..      ...        ...       ...     ...    ...
# 875       3  15.000000    7.2250    True  False
# 671       1  31.000000   52.0000   False   True
# 763       1  36.000000  120.0000    True  False
# 582       2  54.000000   26.0000   False   True
# 823       3  27.000000   12.4750    True  False
#
# [712 rows x 5 columns]

# %%
x_test
# Out:
#      Pclass        Age     Fare  female   male
# 309       1  30.000000  56.9292    True  False
# 480       3   9.000000  46.9000   False   True
# 488       3  30.000000   8.0500   False   True
# 662       1  47.000000  25.5875   False   True
# 555       1  62.000000  26.5500   False   True
# ..      ...        ...      ...     ...    ...
# 146       3  27.000000   7.7958   False   True
# 629       3  29.699118   7.7333   False   True
# 843       3  34.500000   6.4375   False   True
# 479       3   2.000000  12.2875    True  False
# 321       3  27.000000   7.8958   False   True
#
# [179 rows x 5 columns]

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(x_test, y_test)
# Out:
# 0.7541899441340782

# %%
x_test[:10]
# Out:
#      Pclass        Age     Fare  female   male
# 309       1  30.000000  56.9292    True  False
# 480       3   9.000000  46.9000   False   True
# 488       3  30.000000   8.0500   False   True
# 662       1  47.000000  25.5875   False   True
# 555       1  62.000000  26.5500   False   True
# 395       3  22.000000   7.7958   False   True
# 22        3  15.000000   8.0292    True  False
# 324       3  29.699118  69.5500   False   True
# 71        3  16.000000  46.9000    True  False
# 552       3  29.699118   7.8292   False   True

# %%
y_test[:10]
# Out:
# 309    1
# 480    0
# 488    0
# 662    0
# 555    0
# 395    0
# 22     1
# 324    0
# 71     0
# 552    0
# Name: Survived, dtype: int64

# %%
model.predict(x_test[:10])
# Out:
# array([1, 0, 0, 0, 0, 0, 1, 0, 1, 0])

# %%
model.predict_proba(x_test[:10])
# Out:
# array([[0.00254394, 0.99745606],
#        [0.97769553, 0.02230447],
#        [0.99051599, 0.00948401],
#        [0.92080452, 0.07919548],
#        [0.90266585, 0.09733415],
#        [0.98944347, 0.01055653],
#        [0.03461265, 0.96538735],
#        [0.96837741, 0.03162259],
#        [0.0228187 , 0.9771813 ],
#        [0.99048319, 0.00951681]])
